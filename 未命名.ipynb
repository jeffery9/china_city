# %%
import json
import xmltodict
import china_region

jsfile= open('./area_code_2019.json')
xmlfile=open('./zipcode.csv')

d= json.loads(jsfile.read())
zipcodes={}
i=0
for x in xmlfile.readlines():
    if i==0:
        i=i+1
        continue
    
    xx=x.split('"')
#     print('xx',xx)
    addr=xx[1].split(',')
#     print('addr',addr)

    
    zcode=xx[-1].split(',')[1].split('\n')[0]
    co=addr[0]
    st=addr[1]
    key=city=cot =False
    if len(addr)>2:
        city=addr[2]
    if len(addr)>3:
        cot=addr[3]
    if cot:
        key='%s%s'%(city,cot)
#         print(co,st,city,cot)
    else:
        key='%s'%(city)
#         print(co,st,city)
#     print(zcode)
    i=i+1
    zipcodes.update({
        key:zcode
    })
    
# print(zipcode)
    

    
state_map ={
"上海市": "state_cn_SH",
"浙江省": "state_cn_ZJ",
"天津市": "state_cn_TJ",
"安徽省": "state_cn_AH",
"福建省": "state_cn_FJ",
"重庆市": "state_cn_CQ",
"北京市": "state_cn_BJ",
"江西省": "state_cn_JX",
"山东省": "state_cn_SD",
"河南省": "state_cn_HA",
"内蒙古自治区": "state_cn_NM",
"湖北省": "state_cn_HB",
"新疆维吾尔自治区": "state_cn_XJ",
"湖南省": "state_cn_HN",
"宁夏回族自治区": "state_cn_NX",
"广东省": "state_cn_GD",
"西藏自治区": "state_cn_XZ",
"海南省": "state_cn_HI",
"广西壮族自治区": "state_cn_GX",
"四川省": "state_cn_SC",
"河北省": "state_cn_HE",
"贵州省": "state_cn_GZ",
"山西省": "state_cn_SX",
"云南省": "state_cn_YN",
"辽宁省": "state_cn_LN",
"陕西省": "state_cn_SN",
"吉林省": "state_cn_JL",
"甘肃省": "state_cn_GS",
"黑龙江省": "state_cn_HL",
"青海省": "state_cn_QH",
"江苏省": "state_cn_JS",
"台湾省": "state_cn_TW",
"香港特别行政区": "state_cn_HK",
"澳门特别行政区": "state_cn_MO",


    
}


#         <record id="china_city_510802" model="res.city">
#             <field name="state_id" ref="base.state_cn_SC" />
#             <field name="country_id" ref="base.cn" />
#             <field name="zipcode">510802</field>
#             <field name="name">广元市利州区</field>
#         </record>

for x in d:

    state=x['name']
    for c in x['children']:

        city=c['name']
        for z in c['children']:


            code='%s'%(z['code'])
            zipcode=code[:6]
            stateid=state_map.get(state,'')
            
            county=z['name']
            if c['name'] == '市辖区':
                ctname= z['name']
            else:
                if z['name'] =='市辖区':
                    ctname=c['name']
                else:
                    ctname=c['name']+z['name']

            
            xmlid= 'china_city_%s'%(zipcode)
 
            if city=='市辖区':
                city = state
            
            ct=True
            if county=='市辖区':
                county=city
                ct=False
#             print(state)
#             print(city)
#             print(county)
#             xx=china_region.search(province=state,city=city,county=county)


#             if xx:
#                 zip=xx[0]['zipCode']
            if ct:
                ctname= city+county
            else:
                ctname= city
#             print(ctname)
#             print(type(zipcode))
            zip=zipcodes.get(ctname,'')
            print(  '''                  
            <record id="%s" model="res.city">
                <field name="state_id" ref="base.%s" />
                <field name="country_id" ref="base.cn" />
                <field name="zipcode">%s</field>
                <field name="name">%s</field>
            </record>   
               '''%(xmlid,stateid,zip,ctname  ) )
# Out:
#
#             <record id="china_city_110101" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">100010</field>
#                 <field name="name">北京市东城区</field>
#             </record>
#
#
#             <record id="china_city_110102" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">100032</field>
#                 <field name="name">北京市西城区</field>
#             </record>
#
#
#             <record id="china_city_110105" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">100020</field>
#                 <field name="name">北京市朝阳区</field>
#             </record>
#
#
#             <record id="china_city_110106" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">100071</field>
#                 <field name="name">北京市丰台区</field>
#             </record>
#
#
#             <record id="china_city_110107" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">100043</field>
#                 <field name="name">北京市石景山区</field>
#             </record>
#
#
#             <record id="china_city_110108" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">100089</field>
#                 <field name="name">北京市海淀区</field>
#             </record>
#
#
#             <record id="china_city_110109" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">102300</field>
#                 <field name="name">北京市门头沟区</field>
#             </record>
#
#
#             <record id="china_city_110111" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">102488</field>
#                 <field name="name">北京市房山区</field>
#             </record>
#
#
#             <record id="china_city_110112" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">101149</field>
#                 <field name="name">北京市通州区</field>
#             </record>
#
#
#             <record id="china_city_110113" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">101300</field>
#                 <field name="name">北京市顺义区</field>
#             </record>
#
#
#             <record id="china_city_110114" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">102200</field>
#                 <field name="name">北京市昌平区</field>
#             </record>
#
#
#             <record id="china_city_110115" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">102600</field>
#                 <field name="name">北京市大兴区</field>
#             </record>
#
#
#             <record id="china_city_110116" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">101400</field>
#                 <field name="name">北京市怀柔区</field>
#             </record>
#
#
#             <record id="china_city_110117" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">101200</field>
#                 <field name="name">北京市平谷区</field>
#             </record>
#
#
#             <record id="china_city_110118" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">北京市密云区</field>
#             </record>
#
#
#             <record id="china_city_110119" model="res.city">
#                 <field name="state_id" ref="base.state_cn_BJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">北京市延庆区</field>
#             </record>
#
#
#             <record id="china_city_120101" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">300041</field>
#                 <field name="name">天津市和平区</field>
#             </record>
#
#
#             <record id="china_city_120102" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">300171</field>
#                 <field name="name">天津市河东区</field>
#             </record>
#
#
#             <record id="china_city_120103" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">300202</field>
#                 <field name="name">天津市河西区</field>
#             </record>
#
#
#             <record id="china_city_120104" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">300110</field>
#                 <field name="name">天津市南开区</field>
#             </record>
#
#
#             <record id="china_city_120105" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">300143</field>
#                 <field name="name">天津市河北区</field>
#             </record>
#
#
#             <record id="china_city_120106" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">300131</field>
#                 <field name="name">天津市红桥区</field>
#             </record>
#
#
#             <record id="china_city_120110" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">300300</field>
#                 <field name="name">天津市东丽区</field>
#             </record>
#
#
#             <record id="china_city_120111" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">300380</field>
#                 <field name="name">天津市西青区</field>
#             </record>
#
#
#             <record id="china_city_120112" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">300350</field>
#                 <field name="name">天津市津南区</field>
#             </record>
#
#
#             <record id="china_city_120113" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">300400</field>
#                 <field name="name">天津市北辰区</field>
#             </record>
#
#
#             <record id="china_city_120114" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">301700</field>
#                 <field name="name">天津市武清区</field>
#             </record>
#
#
#             <record id="china_city_120115" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">301800</field>
#                 <field name="name">天津市宝坻区</field>
#             </record>
#
#
#             <record id="china_city_120116" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">300451</field>
#                 <field name="name">天津市滨海新区</field>
#             </record>
#
#
#             <record id="china_city_120117" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">天津市宁河区</field>
#             </record>
#
#
#             <record id="china_city_120118" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">天津市静海区</field>
#             </record>
#
#
#             <record id="china_city_120119" model="res.city">
#                 <field name="state_id" ref="base.state_cn_TJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">天津市蓟州区</field>
#             </record>
#
#
#             <record id="china_city_130101" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050011</field>
#                 <field name="name">石家庄市</field>
#             </record>
#
#
#             <record id="china_city_130102" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050011</field>
#                 <field name="name">石家庄市长安区</field>
#             </record>
#
#
#             <record id="china_city_130104" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050091</field>
#                 <field name="name">石家庄市桥西区</field>
#             </record>
#
#
#             <record id="china_city_130105" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050051</field>
#                 <field name="name">石家庄市新华区</field>
#             </record>
#
#
#             <record id="china_city_130107" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050100</field>
#                 <field name="name">石家庄市井陉矿区</field>
#             </record>
#
#
#             <record id="china_city_130108" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050031</field>
#                 <field name="name">石家庄市裕华区</field>
#             </record>
#
#
#             <record id="china_city_130109" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">052160</field>
#                 <field name="name">石家庄市藁城区</field>
#             </record>
#
#
#             <record id="china_city_130110" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050200</field>
#                 <field name="name">石家庄市鹿泉区</field>
#             </record>
#
#
#             <record id="china_city_130111" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">051430</field>
#                 <field name="name">石家庄市栾城区</field>
#             </record>
#
#
#             <record id="china_city_130121" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050300</field>
#                 <field name="name">石家庄市井陉县</field>
#             </record>
#
#
#             <record id="china_city_130123" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050800</field>
#                 <field name="name">石家庄市正定县</field>
#             </record>
#
#
#             <record id="china_city_130125" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050600</field>
#                 <field name="name">石家庄市行唐县</field>
#             </record>
#
#
#             <record id="china_city_130126" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050500</field>
#                 <field name="name">石家庄市灵寿县</field>
#             </record>
#
#
#             <record id="china_city_130127" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">051330</field>
#                 <field name="name">石家庄市高邑县</field>
#             </record>
#
#
#             <record id="china_city_130128" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">052560</field>
#                 <field name="name">石家庄市深泽县</field>
#             </record>
#
#
#             <record id="china_city_130129" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">051230</field>
#                 <field name="name">石家庄市赞皇县</field>
#             </record>
#
#
#             <record id="china_city_130130" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">052460</field>
#                 <field name="name">石家庄市无极县</field>
#             </record>
#
#
#             <record id="china_city_130131" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050400</field>
#                 <field name="name">石家庄市平山县</field>
#             </record>
#
#
#             <record id="china_city_130132" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">051130</field>
#                 <field name="name">石家庄市元氏县</field>
#             </record>
#
#
#             <record id="china_city_130133" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">051530</field>
#                 <field name="name">石家庄市赵县</field>
#             </record>
#
#
#             <record id="china_city_130171" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">石家庄市石家庄高新技术产业开发区</field>
#             </record>
#
#
#             <record id="china_city_130172" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">石家庄市石家庄循环化工园区</field>
#             </record>
#
#
#             <record id="china_city_130181" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">052360</field>
#                 <field name="name">石家庄市辛集市</field>
#             </record>
#
#
#             <record id="china_city_130183" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">052260</field>
#                 <field name="name">石家庄市晋州市</field>
#             </record>
#
#
#             <record id="china_city_130184" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">050700</field>
#                 <field name="name">石家庄市新乐市</field>
#             </record>
#
#
#             <record id="china_city_130201" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">063000</field>
#                 <field name="name">唐山市</field>
#             </record>
#
#
#             <record id="china_city_130202" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">063000</field>
#                 <field name="name">唐山市路南区</field>
#             </record>
#
#
#             <record id="china_city_130203" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">063000</field>
#                 <field name="name">唐山市路北区</field>
#             </record>
#
#
#             <record id="china_city_130204" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">063100</field>
#                 <field name="name">唐山市古冶区</field>
#             </record>
#
#
#             <record id="china_city_130205" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">063021</field>
#                 <field name="name">唐山市开平区</field>
#             </record>
#
#
#             <record id="china_city_130207" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">063300</field>
#                 <field name="name">唐山市丰南区</field>
#             </record>
#
#
#             <record id="china_city_130208" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">064000</field>
#                 <field name="name">唐山市丰润区</field>
#             </record>
#
#
#             <record id="china_city_130209" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">063200</field>
#                 <field name="name">唐山市曹妃甸区</field>
#             </record>
#
#
#             <record id="china_city_130224" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">063500</field>
#                 <field name="name">唐山市滦南县</field>
#             </record>
#
#
#             <record id="china_city_130225" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">063600</field>
#                 <field name="name">唐山市乐亭县</field>
#             </record>
#
#
#             <record id="china_city_130227" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">064300</field>
#                 <field name="name">唐山市迁西县</field>
#             </record>
#
#
#             <record id="china_city_130229" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">064100</field>
#                 <field name="name">唐山市玉田县</field>
#             </record>
#
#
#             <record id="china_city_130271" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">唐山市唐山市芦台经济技术开发区</field>
#             </record>
#
#
#             <record id="china_city_130272" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">唐山市唐山市汉沽管理区</field>
#             </record>
#
#
#             <record id="china_city_130273" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">唐山市唐山高新技术产业开发区</field>
#             </record>
#
#
#             <record id="china_city_130274" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">唐山市河北唐山海港经济开发区</field>
#             </record>
#
#
#             <record id="china_city_130281" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">064200</field>
#                 <field name="name">唐山市遵化市</field>
#             </record>
#
#
#             <record id="china_city_130283" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">064400</field>
#                 <field name="name">唐山市迁安市</field>
#             </record>
#
#
#             <record id="china_city_130284" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">唐山市滦州市</field>
#             </record>
#
#
#             <record id="china_city_130301" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">066000</field>
#                 <field name="name">秦皇岛市</field>
#             </record>
#
#
#             <record id="china_city_130302" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">066000</field>
#                 <field name="name">秦皇岛市海港区</field>
#             </record>
#
#
#             <record id="china_city_130303" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">066200</field>
#                 <field name="name">秦皇岛市山海关区</field>
#             </record>
#
#
#             <record id="china_city_130304" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">066100</field>
#                 <field name="name">秦皇岛市北戴河区</field>
#             </record>
#
#
#             <record id="china_city_130306" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">秦皇岛市抚宁区</field>
#             </record>
#
#
#             <record id="china_city_130321" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">066500</field>
#                 <field name="name">秦皇岛市青龙满族自治县</field>
#             </record>
#
#
#             <record id="china_city_130322" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">066600</field>
#                 <field name="name">秦皇岛市昌黎县</field>
#             </record>
#
#
#             <record id="china_city_130324" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">066400</field>
#                 <field name="name">秦皇岛市卢龙县</field>
#             </record>
#
#
#             <record id="china_city_130371" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">秦皇岛市秦皇岛市经济技术开发区</field>
#             </record>
#
#
#             <record id="china_city_130372" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">秦皇岛市北戴河新区</field>
#             </record>
#
#
#             <record id="china_city_130401" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056002</field>
#                 <field name="name">邯郸市</field>
#             </record>
#
#
#             <record id="china_city_130402" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056001</field>
#                 <field name="name">邯郸市邯山区</field>
#             </record>
#
#
#             <record id="china_city_130403" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056002</field>
#                 <field name="name">邯郸市丛台区</field>
#             </record>
#
#
#             <record id="china_city_130404" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056003</field>
#                 <field name="name">邯郸市复兴区</field>
#             </record>
#
#
#             <record id="china_city_130406" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056200</field>
#                 <field name="name">邯郸市峰峰矿区</field>
#             </record>
#
#
#             <record id="china_city_130407" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">邯郸市肥乡区</field>
#             </record>
#
#
#             <record id="china_city_130408" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">邯郸市永年区</field>
#             </record>
#
#
#             <record id="china_city_130423" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056600</field>
#                 <field name="name">邯郸市临漳县</field>
#             </record>
#
#
#             <record id="china_city_130424" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056700</field>
#                 <field name="name">邯郸市成安县</field>
#             </record>
#
#
#             <record id="china_city_130425" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056900</field>
#                 <field name="name">邯郸市大名县</field>
#             </record>
#
#
#             <record id="china_city_130426" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056400</field>
#                 <field name="name">邯郸市涉县</field>
#             </record>
#
#
#             <record id="china_city_130427" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056500</field>
#                 <field name="name">邯郸市磁县</field>
#             </record>
#
#
#             <record id="china_city_130430" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">057450</field>
#                 <field name="name">邯郸市邱县</field>
#             </record>
#
#
#             <record id="china_city_130431" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">057350</field>
#                 <field name="name">邯郸市鸡泽县</field>
#             </record>
#
#
#             <record id="china_city_130432" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">057650</field>
#                 <field name="name">邯郸市广平县</field>
#             </record>
#
#
#             <record id="china_city_130433" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">057750</field>
#                 <field name="name">邯郸市馆陶县</field>
#             </record>
#
#
#             <record id="china_city_130434" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056800</field>
#                 <field name="name">邯郸市魏县</field>
#             </record>
#
#
#             <record id="china_city_130435" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">057250</field>
#                 <field name="name">邯郸市曲周县</field>
#             </record>
#
#
#             <record id="china_city_130471" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">邯郸市邯郸经济技术开发区</field>
#             </record>
#
#
#             <record id="china_city_130473" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">邯郸市邯郸冀南新区</field>
#             </record>
#
#
#             <record id="china_city_130481" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">056300</field>
#                 <field name="name">邯郸市武安市</field>
#             </record>
#
#
#             <record id="china_city_130501" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054001</field>
#                 <field name="name">邢台市</field>
#             </record>
#
#
#             <record id="china_city_130502" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054001</field>
#                 <field name="name">邢台市桥东区</field>
#             </record>
#
#
#             <record id="china_city_130503" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054000</field>
#                 <field name="name">邢台市桥西区</field>
#             </record>
#
#
#             <record id="china_city_130521" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054001</field>
#                 <field name="name">邢台市邢台县</field>
#             </record>
#
#
#             <record id="china_city_130522" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054300</field>
#                 <field name="name">邢台市临城县</field>
#             </record>
#
#
#             <record id="china_city_130523" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054200</field>
#                 <field name="name">邢台市内丘县</field>
#             </record>
#
#
#             <record id="china_city_130524" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">055450</field>
#                 <field name="name">邢台市柏乡县</field>
#             </record>
#
#
#             <record id="china_city_130525" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">055350</field>
#                 <field name="name">邢台市隆尧县</field>
#             </record>
#
#
#             <record id="china_city_130526" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">055150</field>
#                 <field name="name">邢台市任县</field>
#             </record>
#
#
#             <record id="china_city_130527" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054400</field>
#                 <field name="name">邢台市南和县</field>
#             </record>
#
#
#             <record id="china_city_130528" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">055550</field>
#                 <field name="name">邢台市宁晋县</field>
#             </record>
#
#
#             <record id="china_city_130529" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">055250</field>
#                 <field name="name">邢台市巨鹿县</field>
#             </record>
#
#
#             <record id="china_city_130530" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">055650</field>
#                 <field name="name">邢台市新河县</field>
#             </record>
#
#
#             <record id="china_city_130531" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054600</field>
#                 <field name="name">邢台市广宗县</field>
#             </record>
#
#
#             <record id="china_city_130532" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054500</field>
#                 <field name="name">邢台市平乡县</field>
#             </record>
#
#
#             <record id="china_city_130533" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054700</field>
#                 <field name="name">邢台市威县</field>
#             </record>
#
#
#             <record id="china_city_130534" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054800</field>
#                 <field name="name">邢台市清河县</field>
#             </record>
#
#
#             <record id="china_city_130535" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054900</field>
#                 <field name="name">邢台市临西县</field>
#             </record>
#
#
#             <record id="china_city_130571" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">邢台市河北邢台经济开发区</field>
#             </record>
#
#
#             <record id="china_city_130581" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">055750</field>
#                 <field name="name">邢台市南宫市</field>
#             </record>
#
#
#             <record id="china_city_130582" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">054100</field>
#                 <field name="name">邢台市沙河市</field>
#             </record>
#
#
#             <record id="china_city_130601" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">071052</field>
#                 <field name="name">保定市</field>
#             </record>
#
#
#             <record id="china_city_130602" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">保定市竞秀区</field>
#             </record>
#
#
#             <record id="china_city_130606" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">保定市莲池区</field>
#             </record>
#
#
#             <record id="china_city_130607" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">保定市满城区</field>
#             </record>
#
#
#             <record id="china_city_130608" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">保定市清苑区</field>
#             </record>
#
#
#             <record id="china_city_130609" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">保定市徐水区</field>
#             </record>
#
#
#             <record id="china_city_130623" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">074100</field>
#                 <field name="name">保定市涞水县</field>
#             </record>
#
#
#             <record id="china_city_130624" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">073200</field>
#                 <field name="name">保定市阜平县</field>
#             </record>
#
#
#             <record id="china_city_130626" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">072650</field>
#                 <field name="name">保定市定兴县</field>
#             </record>
#
#
#             <record id="china_city_130627" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">072350</field>
#                 <field name="name">保定市唐县</field>
#             </record>
#
#
#             <record id="china_city_130628" model="res.city">
#                 <field name="state_id" ref="base.state_cn_HE" />
# ...
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">844800</field>
#                 <field name="name">喀什地区泽普县</field>
#             </record>
#
#
#             <record id="china_city_653125" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">844700</field>
#                 <field name="name">喀什地区莎车县</field>
#             </record>
#
#
#             <record id="china_city_653126" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">844900</field>
#                 <field name="name">喀什地区叶城县</field>
#             </record>
#
#
#             <record id="china_city_653127" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">844600</field>
#                 <field name="name">喀什地区麦盖提县</field>
#             </record>
#
#
#             <record id="china_city_653128" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">844400</field>
#                 <field name="name">喀什地区岳普湖县</field>
#             </record>
#
#
#             <record id="china_city_653129" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">844300</field>
#                 <field name="name">喀什地区伽师县</field>
#             </record>
#
#
#             <record id="china_city_653130" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">843800</field>
#                 <field name="name">喀什地区巴楚县</field>
#             </record>
#
#
#             <record id="china_city_653131" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">845250</field>
#                 <field name="name">喀什地区塔什库尔干塔吉克自治县</field>
#             </record>
#
#
#             <record id="china_city_653201" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">848000</field>
#                 <field name="name">和田地区和田市</field>
#             </record>
#
#
#             <record id="china_city_653221" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">848000</field>
#                 <field name="name">和田地区和田县</field>
#             </record>
#
#
#             <record id="china_city_653222" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">848100</field>
#                 <field name="name">和田地区墨玉县</field>
#             </record>
#
#
#             <record id="china_city_653223" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">845150</field>
#                 <field name="name">和田地区皮山县</field>
#             </record>
#
#
#             <record id="china_city_653224" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">848200</field>
#                 <field name="name">和田地区洛浦县</field>
#             </record>
#
#
#             <record id="china_city_653225" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">848300</field>
#                 <field name="name">和田地区策勒县</field>
#             </record>
#
#
#             <record id="china_city_653226" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">848400</field>
#                 <field name="name">和田地区于田县</field>
#             </record>
#
#
#             <record id="china_city_653227" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">848500</field>
#                 <field name="name">和田地区民丰县</field>
#             </record>
#
#
#             <record id="china_city_654002" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">835000</field>
#                 <field name="name">伊犁哈萨克自治州伊宁市</field>
#             </record>
#
#
#             <record id="china_city_654003" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">833200</field>
#                 <field name="name">伊犁哈萨克自治州奎屯市</field>
#             </record>
#
#
#             <record id="china_city_654004" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">835221</field>
#                 <field name="name">伊犁哈萨克自治州霍尔果斯市</field>
#             </record>
#
#
#             <record id="china_city_654021" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">835100</field>
#                 <field name="name">伊犁哈萨克自治州伊宁县</field>
#             </record>
#
#
#             <record id="china_city_654022" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">835300</field>
#                 <field name="name">伊犁哈萨克自治州察布查尔锡伯自治县</field>
#             </record>
#
#
#             <record id="china_city_654023" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">835200</field>
#                 <field name="name">伊犁哈萨克自治州霍城县</field>
#             </record>
#
#
#             <record id="china_city_654024" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">835400</field>
#                 <field name="name">伊犁哈萨克自治州巩留县</field>
#             </record>
#
#
#             <record id="china_city_654025" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">835800</field>
#                 <field name="name">伊犁哈萨克自治州新源县</field>
#             </record>
#
#
#             <record id="china_city_654026" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">835600</field>
#                 <field name="name">伊犁哈萨克自治州昭苏县</field>
#             </record>
#
#
#             <record id="china_city_654027" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">835500</field>
#                 <field name="name">伊犁哈萨克自治州特克斯县</field>
#             </record>
#
#
#             <record id="china_city_654028" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">835700</field>
#                 <field name="name">伊犁哈萨克自治州尼勒克县</field>
#             </record>
#
#
#             <record id="china_city_654201" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">834700</field>
#                 <field name="name">塔城地区塔城市</field>
#             </record>
#
#
#             <record id="china_city_654202" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">833000</field>
#                 <field name="name">塔城地区乌苏市</field>
#             </record>
#
#
#             <record id="china_city_654221" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">834600</field>
#                 <field name="name">塔城地区额敏县</field>
#             </record>
#
#
#             <record id="china_city_654223" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">832100</field>
#                 <field name="name">塔城地区沙湾县</field>
#             </record>
#
#
#             <record id="china_city_654224" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">834500</field>
#                 <field name="name">塔城地区托里县</field>
#             </record>
#
#
#             <record id="china_city_654225" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">834800</field>
#                 <field name="name">塔城地区裕民县</field>
#             </record>
#
#
#             <record id="china_city_654226" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">834400</field>
#                 <field name="name">塔城地区和布克赛尔蒙古自治县</field>
#             </record>
#
#
#             <record id="china_city_654301" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">836500</field>
#                 <field name="name">阿勒泰地区阿勒泰市</field>
#             </record>
#
#
#             <record id="china_city_654321" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">836600</field>
#                 <field name="name">阿勒泰地区布尔津县</field>
#             </record>
#
#
#             <record id="china_city_654322" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">836100</field>
#                 <field name="name">阿勒泰地区富蕴县</field>
#             </record>
#
#
#             <record id="china_city_654323" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">836400</field>
#                 <field name="name">阿勒泰地区福海县</field>
#             </record>
#
#
#             <record id="china_city_654324" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">836700</field>
#                 <field name="name">阿勒泰地区哈巴河县</field>
#             </record>
#
#
#             <record id="china_city_654325" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">836200</field>
#                 <field name="name">阿勒泰地区青河县</field>
#             </record>
#
#
#             <record id="china_city_654326" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode">836800</field>
#                 <field name="name">阿勒泰地区吉木乃县</field>
#             </record>
#
#
#             <record id="china_city_659001" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">自治区直辖县级行政区划石河子市</field>
#             </record>
#
#
#             <record id="china_city_659002" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">自治区直辖县级行政区划阿拉尔市</field>
#             </record>
#
#
#             <record id="china_city_659003" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">自治区直辖县级行政区划图木舒克市</field>
#             </record>
#
#
#             <record id="china_city_659004" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">自治区直辖县级行政区划五家渠市</field>
#             </record>
#
#
#             <record id="china_city_659006" model="res.city">
#                 <field name="state_id" ref="base.state_cn_XJ" />
#                 <field name="country_id" ref="base.cn" />
#                 <field name="zipcode"></field>
#                 <field name="name">自治区直辖县级行政区划铁门关市</field>
#             </record>

# %%
import json
import xmltodict
import china_region

jsfile= open('./area_code_2019.json')
xmlfile=open('./zipcode.csv')

d= json.loads(jsfile.read())
zipcode={}
i=0
for x in xmlfile.readlines():
    if i==0:
        i=i+1
        continue
    
    xx=x.split('"')
#     print('xx',xx)
    addr=xx[1].split(',')
#     print('addr',addr)

    
    zcode=xx[-1].split(',')[1].split('\n')[0]
    co=addr[0]
    st=addr[1]
    cot =False
    if len(addr)>2:
        city=addr[2]
    if len(addr)>3:
        cot=addr[3]
    if cot:
        key='%s%s'%(city,cot)
#         print(co,st,city,cot)
    else:
        key='%s'%(city)
#         print(co,st,city)
#     print(zcode)
    i=i+1
    zipcode.update({
        key:zcode
    })
    
print(zipcode)
# Out:
# {'自治区直辖县级行政区划': '', '北京市': '', '北京市东城区': '100010', '北京市西城区': '100032', '北京市朝阳区': '100020', '北京市丰台区': '100071', '北京市石景山区': '100043', '北京市海淀区': '100089', '北京市门头沟区': '102300', '北京市房山区': '102488', '北京市通州区': '101149', '北京市顺义区': '101300', '北京市昌平区': '102200', '北京市大兴区': '102600', '北京市怀柔区': '101400', '北京市平谷区': '101200', '北京市密云县': '101500', '北京市延庆县': '102100', '天津市': '', '天津市和平区': '300041', '天津市河东区': '300171', '天津市河西区': '300202', '天津市南开区': '300110', '天津市河北区': '300143', '天津市红桥区': '300131', '天津市东丽区': '300300', '天津市西青区': '300380', '天津市津南区': '300350', '天津市北辰区': '300400', '天津市武清区': '301700', '天津市宝坻区': '301800', '天津市滨海新区': '300451', '天津市宁河县': '301500', '天津市静海县': '301600', '天津市蓟县': '301900', '石家庄市': '050011', '石家庄市长安区': '050011', '石家庄市桥西区': '050091', '石家庄市新华区': '050051', '石家庄市井陉矿区': '050100', '石家庄市裕华区': '050031', '石家庄市藁城区': '052160', '石家庄市鹿泉区': '050200', '石家庄市栾城区': '051430', '石家庄市井陉县': '050300', '石家庄市正定县': '050800', '石家庄市行唐县': '050600', '石家庄市灵寿县': '050500', '石家庄市高邑县': '051330', '石家庄市深泽县': '052560', '石家庄市赞皇县': '051230', '石家庄市无极县': '052460', '石家庄市平山县': '050400', '石家庄市元氏县': '051130', '石家庄市赵县': '051530', '石家庄市辛集市': '052360', '石家庄市晋州市': '052260', '石家庄市新乐市': '050700', '唐山市': '063000', '唐山市路南区': '063000', '唐山市路北区': '063000', '唐山市古冶区': '063100', '唐山市开平区': '063021', '唐山市丰南区': '063300', '唐山市丰润区': '064000', '唐山市曹妃甸区': '063200', '唐山市滦县': '063700', '唐山市滦南县': '063500', '唐山市乐亭县': '063600', '唐山市迁西县': '064300', '唐山市玉田县': '064100', '唐山市遵化市': '064200', '唐山市迁安市': '064400', '秦皇岛市': '066000', '秦皇岛市海港区': '066000', '秦皇岛市山海关区': '066200', '秦皇岛市北戴河区': '066100', '秦皇岛市青龙满族自治县': '066500', '秦皇岛市昌黎县': '066600', '秦皇岛市抚宁县': '066300', '秦皇岛市卢龙县': '066400', '邯郸市': '056002', '邯郸市邯山区': '056001', '邯郸市丛台区': '056002', '邯郸市复兴区': '056003', '邯郸市峰峰矿区': '056200', '邯郸市邯郸县': '056101', '邯郸市临漳县': '056600', '邯郸市成安县': '056700', '邯郸市大名县': '056900', '邯郸市涉县': '056400', '邯郸市磁县': '056500', '邯郸市肥乡县': '057550', '邯郸市永年县': '057150', '邯郸市邱县': '057450', '邯郸市鸡泽县': '057350', '邯郸市广平县': '057650', '邯郸市馆陶县': '057750', '邯郸市魏县': '056800', '邯郸市曲周县': '057250', '邯郸市武安市': '056300', '邢台市': '054001', '邢台市桥东区': '054001', '邢台市桥西区': '054000', '邢台市邢台县': '054001', '邢台市临城县': '054300', '邢台市内丘县': '054200', '邢台市柏乡县': '055450', '邢台市隆尧县': '055350', '邢台市任县': '055150', '邢台市南和县': '054400', '邢台市宁晋县': '055550', '邢台市巨鹿县': '055250', '邢台市新河县': '055650', '邢台市广宗县': '054600', '邢台市平乡县': '054500', '邢台市威县': '054700', '邢台市清河县': '054800', '邢台市临西县': '054900', '邢台市南宫市': '055750', '邢台市沙河市': '054100', '保定市': '071052', '保定市新市区': '071051', '保定市北市区': '071000', '保定市南市区': '071001', '保定市满城县': '072150', '保定市清苑县': '071100', '保定市涞水县': '074100', '保定市阜平县': '073200', '保定市徐水县': '072550', '保定市定兴县': '072650', '保定市唐县': '072350', '保定市高阳县': '071500', '保定市容城县': '071700', '保定市涞源县': '074300', '保定市望都县': '072450', '保定市安新县': '071600', '保定市易县': '074200', '保定市曲阳县': '073100', '保定市蠡县': '071400', '保定市顺平县': '072250', '保定市博野县': '071300', '保定市雄县': '071800', '保定市涿州市': '072750', '保定市定州市': '073000', '保定市安国市': '071200', '保定市高碑店市': '074000', '张家口市': '075000', '张家口市桥东区': '075000', '张家口市桥西区': '075061', '张家口市宣化区': '075100', '张家口市下花园区': '075300', '张家口市宣化县': '075100', '张家口市张北县': '076450', '张家口市康保县': '076650', '张家口市沽源县': '076550', '张家口市尚义县': '076750', '张家口市蔚县': '075700', '张家口市阳原县': '075800', '张家口市怀安县': '076150', '张家口市万全县': '076250', '张家口市怀来县': '075400', '张家口市涿鹿县': '075600', '张家口市赤城县': '075500', '张家口市崇礼县': '076350', '承德市': '067000', '承德市双桥区': '067000', '承德市双滦区': '067001', '承德市鹰手营子矿区': '067200', '承德市承德县': '067400', '承德市兴隆县': '067300', '承德市平泉县': '067500', '承德市滦平县': '068250', '承德市隆化县': '068150', '承德市丰宁满族自治县': '068350', '承德市宽城满族自治县': '067600', '承德市围场满族蒙古族自治县': '068450', '沧州市': '061001', '沧州市新华区': '061000', '沧州市运河区': '061001', '沧州市沧县': '061000', '沧州市青县': '062650', '沧州市东光县': '061600', '沧州市海兴县': '061200', '沧州市盐山县': '061300', '沧州市肃宁县': '062350', '沧州市南皮县': '061500', '沧州市吴桥县': '061800', '沧州市献县': '062250', '沧州市孟村回族自治县': '061400', '沧州市泊头市': '062150', '沧州市任丘市': '062550', '沧州市黄骅市': '061100', '沧州市河间市': '062450', '廊坊市': '065000', '廊坊市安次区': '065000', '廊坊市广阳区': '065000', '廊坊市固安县': '065500', '廊坊市永清县': '065600',  ...
